# %% [markdown]
# <a href="https://colab.research.google.com/github/pontabi/scrapbook/blob/main/pd_plt_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/video_views.csv')
df.head()
# Out:
#           日付   時   分    視聴回数
# 0  2023/4/28  18  30       0
# 1  2023/4/29  11  30  103261
# 2  2023/4/29  12   0  104628
# 3  2023/4/29  12  30  106329
# 4  2023/4/29  13   0  109468

# %%
df.describe()
# Out:
#                  時            分          視聴回数
# count  2449.000000  2449.000000  2.449000e+03
# mean     11.503062    15.030625  8.910846e+05
# std       6.914222    15.003032  2.350430e+05
# min       0.000000     0.000000  0.000000e+00
# 25%       6.000000     0.000000  8.605190e+05
# 50%      11.000000    30.000000  9.749190e+05
# 75%      17.000000    30.000000  1.043903e+06
# max      23.000000    30.000000  1.108569e+06

# %%
df['時'] == 18
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2444    False
# 2445    False
# 2446    False
# 2447    False
# 2448    False
# Name: 時, Length: 2449, dtype: bool

# %%
df[df['時'] == 18]
# Out:
#              日付   時   分     視聴回数
# 0     2023/4/28  18  30        0
# 14    2023/4/29  18   0   128596
# 15    2023/4/29  18  30   130213
# 62    2023/4/30  18   0   198999
# 63    2023/4/30  18  30   202782
# ...         ...  ..  ..      ...
# 2343  2023/6/16  18  30  1097838
# 2390  2023/6/17  18   0  1103192
# 2391  2023/6/17  18  30  1103295
# 2438  2023/6/18  18   0  1107668
# 2439  2023/6/18  18  30  1107782
#
# [103 rows x 4 columns]

# %%
df_day = df[(df['時'] == 18) & (df['分'] == 30)]
df_day.head()
# Out:
#             日付   時   分    視聴回数
# 0    2023/4/28  18  30       0
# 15   2023/4/29  18  30  130213
# 63   2023/4/30  18  30  202782
# 111   2023/5/1  18  30  286482
# 159   2023/5/2  18  30  346963

# %%
df_day['視聴回数']
# Out:
# 0             0
# 15       130213
# 63       202782
# 111      286482
# 159      346963
# 208      427535
# 256      509319
# 304      589960
# 352      652500
# 400      710048
# 448      754442
# 496      791012
# 544      822595
# 592      848245
# 640      867318
# 688      884025
# 736      897353
# 784      907781
# 832      917159
# 880      925437
# 928      932508
# 976      939694
# 1024     947700
# 1072     955020
# 1123     961051
# 1171     966910
# 1219     974398
# 1267     979845
# 1315     985019
# 1363     990509
# 1411     997072
# 1468    1003468
# 1516    1009312
# 1576    1014688
# 1624    1019523
# 1672    1024717
# 1720    1030294
# 1768    1035945
# 1816    1040928
# 1864    1045906
# 1912    1050921
# 1960    1055506
# 2007    1060757
# 2055    1065625
# 2103    1070937
# 2151    1075987
# 2199    1081156
# 2247    1086945
# 2295    1092672
# 2343    1097838
# 2391    1103295
# 2439    1107782
# Name: 視聴回数, dtype: int64

# %%
df_day.iloc[0]
# Out:
# 日付      2023/4/28
# 時              18
# 分              30
# 視聴回数            0
# Name: 0, dtype: object

# %%
df_day.loc[0]
# Out:
# 日付      2023/4/28
# 時              18
# 分              30
# 視聴回数            0
# Name: 0, dtype: object

# %%
df_day.iloc[0]['視聴回数']
# Out:
# 0

# %%
df_day.loc[0, '視聴回数']
# Out:
# 0

# %%
df_day1 = df_day.reset_index(drop=True)
df_day1.head()
# Out:
#           日付   時   分    視聴回数
# 0  2023/4/28  18  30       0
# 1  2023/4/29  18  30  130213
# 2  2023/4/30  18  30  202782
# 3   2023/5/1  18  30  286482
# 4   2023/5/2  18  30  346963

# %%
import matplotlib.pyplot as plt

plt.plot(df_day['日付'], df_day['視聴回数'])

# %%
import matplotlib.pyplot as plt

plt.plot(range(len(df_day1)), df_day['視聴回数'])

# %%
# diff() 一つ前のRecordとの差分
df_day1['diff'] = df_day1['視聴回数'].diff()
df_day1.head()
# Out:
#           日付   時   分    視聴回数      diff
# 0  2023/4/28  18  30       0       NaN
# 1  2023/4/29  18  30  130213  130213.0
# 2  2023/4/30  18  30  202782   72569.0
# 3   2023/5/1  18  30  286482   83700.0
# 4   2023/5/2  18  30  346963   60481.0

# %%
plt.bar(range(len(df_day1)), df_day1['diff'])
# Out:
# <BarContainer object of 52 artists>
